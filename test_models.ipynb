# %%
from tensorflow import keras
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
from models import model_2d, model_1d, model_1d_rnn, model_1d_rnn_2

# %%
from seq2mat import DataGenerator, seq_class, label_dict

# %%
model_1d.load_weights('model_1d.model.best.hdf5')
model_2d.load_weights('model_2d.model.best.hdf5')
model_1d_rnn.load_weights('model_1d_rnn.model.best.hdf5')
model_1d_rnn_2.load_weights('model_1d_rnn_2.model.best.hdf5')

# %%
train_val, test, y_train_val, y_test = train_test_split(seq_class.index, seq_class['label'], test_size=0.1, random_state=42)

# %%
params_1d = {
        'batch_size': 4, 
        'dim': (1502, 31),
        'n_classes': 25, 
        'shuffle': False,
        'struct': '1d',
        'random_insert': False
    }

test_generator_1d = DataGenerator(test, seq_class['label'], **params_1d)

# %%
class_dict = {val: key for key, val in label_dict.items()}

# %%
preds = [class_dict[x] for x in model_1d.predict_generator(test_generator_1d, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2068\4167444610.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   preds = [class_dict[x] for x in model_1d.predict_generator(test_generator_1d, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]
# 949/949 [==============================] - 239s 198ms/step

# %%
preds
# Out:
# ['TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  'TRANSCRIPTION',
#  ...]

# %%
len(preds)
# Out:
# 3796

# %%
len(test)
# Out:
# 3796

# %%
print(classification_report(seq_class['classification'][test], preds))
# Out:
#                                    precision    recall  f1-score   support
#
#                     CELL ADHESION       0.00      0.00      0.00        63
#                         CHAPERONE       0.00      0.00      0.00        48
#                       DNA BINDING       0.00      0.00      0.00        81
#                ELECTRON TRANSPORT       0.00      0.00      0.00        68
#                         HYDROLASE       0.00      0.00      0.00      1012
#     HYDROLASE/HYDROLASE INHIBITOR       0.00      0.00      0.00        96
#                     IMMUNE SYSTEM       0.00      0.00      0.00        51
#                         ISOMERASE       0.00      0.00      0.00        87
#                            LIGASE       0.00      0.00      0.00        89
#                             LYASE       0.00      0.00      0.00       141
#                          MEMBRANE       0.00      0.00      0.00        66
#                     METAL BINDING       0.00      0.00      0.00        70
#                    OXIDOREDUCTASE       0.00      0.00      0.00       443
#                   PROTEIN BINDING       0.00      0.00      0.00        73
#                       RNA BINDING       0.00      0.00      0.00        50
#                         SIGNALING       0.00      0.00      0.00       101
#                        STRUCTURAL       0.00      0.00      0.00        51
#                     SUGAR BINDING       0.00      0.00      0.00        33
#                             TOXIN       0.00      0.00      0.00        58
#                     TRANSCRIPTION       0.04      1.00      0.07       134
#                       TRANSFERASE       0.00      0.00      0.00       597
# TRANSFERASE/TRANSFERASE INHIBITOR       0.00      0.00      0.00       143
#                         TRANSPORT       0.00      0.00      0.00       125
#                  UNKNOWN FUNCTION       0.00      0.00      0.00        48
#                             VIRAL       0.00      0.00      0.00        68
#
#                          accuracy                           0.04      3796
#                         macro avg       0.00      0.04      0.00      3796
#                      weighted avg       0.00      0.04      0.00      3796
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
params_2d = {
        'batch_size': 4, 
        'dim': (3072, 8, 6),
        'n_classes': 25, 
        'shuffle': False,
        'struct': '2d'
    }

test_generator_2d = DataGenerator(test, seq_class['label'], **params_2d)

preds = [class_dict[x] for x in model_2d.predict_generator(test_generator_2d, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]

print(classification_report(seq_class['classification'][test], preds))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2068\346787265.py:11: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   preds = [class_dict[x] for x in model_2d.predict_generator(test_generator_2d, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]
# 949/949 [==============================] - 261s 206ms/step
#                                    precision    recall  f1-score   support
#
#                     CELL ADHESION       0.00      0.00      0.00        63
#                         CHAPERONE       0.00      0.00      0.00        48
#                       DNA BINDING       0.00      0.00      0.00        81
#                ELECTRON TRANSPORT       0.00      0.00      0.00        68
#                         HYDROLASE       0.00      0.00      0.00      1012
#     HYDROLASE/HYDROLASE INHIBITOR       0.03      1.00      0.05        96
#                     IMMUNE SYSTEM       0.00      0.00      0.00        51
#                         ISOMERASE       0.00      0.00      0.00        87
#                            LIGASE       0.00      0.00      0.00        89
#                             LYASE       0.00      0.00      0.00       141
#                          MEMBRANE       0.00      0.00      0.00        66
#                     METAL BINDING       0.00      0.00      0.00        70
#                    OXIDOREDUCTASE       0.00      0.00      0.00       443
#                   PROTEIN BINDING       0.00      0.00      0.00        73
#                       RNA BINDING       0.00      0.00      0.00        50
#                         SIGNALING       0.00      0.00      0.00       101
#                        STRUCTURAL       0.00      0.00      0.00        51
#                     SUGAR BINDING       0.00      0.00      0.00        33
#                             TOXIN       0.00      0.00      0.00        58
#                     TRANSCRIPTION       0.00      0.00      0.00       134
#                       TRANSFERASE       0.00      0.00      0.00       597
# TRANSFERASE/TRANSFERASE INHIBITOR       0.00      0.00      0.00       143
#                         TRANSPORT       0.00      0.00      0.00       125
#                  UNKNOWN FUNCTION       0.00      0.00      0.00        48
#                             VIRAL       0.00      0.00      0.00        68
#
#                          accuracy                           0.03      3796
#                         macro avg       0.00      0.04      0.00      3796
#                      weighted avg       0.00      0.03      0.00      3796
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(seq_class['classification'][test][test_generator_2d.indexes], preds))
# Out:
#                                    precision    recall  f1-score   support
#
#                     CELL ADHESION       0.00      0.00      0.00        63
#                         CHAPERONE       0.00      0.00      0.00        48
#                       DNA BINDING       0.00      0.00      0.00        81
#                ELECTRON TRANSPORT       0.00      0.00      0.00        68
#                         HYDROLASE       0.00      0.00      0.00      1012
#     HYDROLASE/HYDROLASE INHIBITOR       0.03      1.00      0.05        96
#                     IMMUNE SYSTEM       0.00      0.00      0.00        51
#                         ISOMERASE       0.00      0.00      0.00        87
#                            LIGASE       0.00      0.00      0.00        89
#                             LYASE       0.00      0.00      0.00       141
#                          MEMBRANE       0.00      0.00      0.00        66
#                     METAL BINDING       0.00      0.00      0.00        70
#                    OXIDOREDUCTASE       0.00      0.00      0.00       443
#                   PROTEIN BINDING       0.00      0.00      0.00        73
#                       RNA BINDING       0.00      0.00      0.00        50
#                         SIGNALING       0.00      0.00      0.00       101
#                        STRUCTURAL       0.00      0.00      0.00        51
#                     SUGAR BINDING       0.00      0.00      0.00        33
#                             TOXIN       0.00      0.00      0.00        58
#                     TRANSCRIPTION       0.00      0.00      0.00       134
#                       TRANSFERASE       0.00      0.00      0.00       597
# TRANSFERASE/TRANSFERASE INHIBITOR       0.00      0.00      0.00       143
#                         TRANSPORT       0.00      0.00      0.00       125
#                  UNKNOWN FUNCTION       0.00      0.00      0.00        48
#                             VIRAL       0.00      0.00      0.00        68
#
#                          accuracy                           0.03      3796
#                         macro avg       0.00      0.04      0.00      3796
#                      weighted avg       0.00      0.03      0.00      3796
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
params_1d_rnn = {
        'batch_size': 4, 
        'dim': (1502, 31),
        'n_classes': 25, 
        'shuffle': True,
        'struct': '1d',
        'random_insert': False,
        'rnn': True
    }

test_generator_1d_rnn = DataGenerator(test, seq_class['label'], **params_1d_rnn)

preds = [class_dict[x] for x in model_1d_rnn.predict_generator(test_generator_1d_rnn, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]

print(classification_report(seq_class['classification'][test][test_generator_1d_rnn.indexes], preds))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2068\3620570550.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   preds = [class_dict[x] for x in model_1d_rnn.predict_generator(test_generator_1d_rnn, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]
# 949/949 [==============================] - 1458s 1s/step
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                    precision    recall  f1-score   support
#
#                     CELL ADHESION       0.00      0.00      0.00        63
#                         CHAPERONE       0.00      0.00      0.00        48
#                       DNA BINDING       0.00      0.00      0.00        81
#                ELECTRON TRANSPORT       0.00      0.00      0.00        68
#                         HYDROLASE       0.00      0.00      0.00      1012
#     HYDROLASE/HYDROLASE INHIBITOR       0.04      0.20      0.06        96
#                     IMMUNE SYSTEM       0.00      0.00      0.00        51
#                         ISOMERASE       0.00      0.00      0.00        87
#                            LIGASE       0.00      0.00      0.00        89
#                             LYASE       0.00      0.00      0.00       141
#                          MEMBRANE       0.00      0.00      0.00        66
#                     METAL BINDING       0.00      0.00      0.00        70
#                    OXIDOREDUCTASE       0.00      0.00      0.00       443
#                   PROTEIN BINDING       0.00      0.00      0.00        73
#                       RNA BINDING       0.00      0.00      0.00        50
#                         SIGNALING       0.00      0.00      0.00       101
#                        STRUCTURAL       0.00      0.00      0.00        51
#                     SUGAR BINDING       0.00      0.00      0.00        33
#                             TOXIN       0.00      0.00      0.00        58
#                     TRANSCRIPTION       0.01      0.03      0.02       134
#                       TRANSFERASE       0.00      0.00      0.00       597
# TRANSFERASE/TRANSFERASE INHIBITOR       0.00      0.00      0.00       143
#                         TRANSPORT       0.00      0.00      0.00       125
#                  UNKNOWN FUNCTION       0.00      0.00      0.00        48
#                             VIRAL       0.01      0.60      0.03        68
#
#                          accuracy                           0.02      3796
#                         macro avg       0.00      0.03      0.00      3796
#                      weighted avg       0.00      0.02      0.00      3796
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
params_1d_rnn_2 = {
        'batch_size': 4, 
        'dim': (1502, 36),
        'n_classes': 25, 
        'shuffle': False,
        'struct': '2d',
        'random_insert': False,
        'rnn': True
    }

test_generator_1d_rnn_2 = DataGenerator(test, seq_class['label'], **params_1d_rnn_2)

preds = [class_dict[x] for x in model_1d_rnn_2.predict_generator(test_generator_1d_rnn_2, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]

print(classification_report(seq_class['classification'][test][test_generator_1d_rnn_2.indexes], preds))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2068\3401776037.py:13: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   preds = [class_dict[x] for x in model_1d_rnn_2.predict_generator(test_generator_1d_rnn_2, verbose=1, use_multiprocessing=True, workers=4).argmax(axis=-1)]
# 949/949 [==============================] - 89s 50ms/step
#                                    precision    recall  f1-score   support
#
#                     CELL ADHESION       0.02      0.76      0.03        63
#                         CHAPERONE       0.00      0.00      0.00        48
#                       DNA BINDING       0.00      0.00      0.00        81
#                ELECTRON TRANSPORT       0.00      0.00      0.00        68
#                         HYDROLASE       0.00      0.00      0.00      1012
#     HYDROLASE/HYDROLASE INHIBITOR       0.00      0.00      0.00        96
#                     IMMUNE SYSTEM       0.01      0.16      0.02        51
#                         ISOMERASE       0.00      0.00      0.00        87
#                            LIGASE       0.00      0.00      0.00        89
#                             LYASE       0.00      0.00      0.00       141
#                          MEMBRANE       0.00      0.00      0.00        66
#                     METAL BINDING       0.00      0.00      0.00        70
#                    OXIDOREDUCTASE       0.00      0.00      0.00       443
#                   PROTEIN BINDING       0.00      0.00      0.00        73
#                       RNA BINDING       0.00      0.00      0.00        50
#                         SIGNALING       0.00      0.00      0.00       101
#                        STRUCTURAL       0.00      0.00      0.00        51
#                     SUGAR BINDING       0.00      0.00      0.00        33
#                             TOXIN       0.00      0.00      0.00        58
#                     TRANSCRIPTION       0.00      0.00      0.00       134
#                       TRANSFERASE       0.00      0.00      0.00       597
# TRANSFERASE/TRANSFERASE INHIBITOR       0.00      0.00      0.00       143
#                         TRANSPORT       0.00      0.00      0.00       125
#                  UNKNOWN FUNCTION       0.00      0.00      0.00        48
#                             VIRAL       0.00      0.00      0.00        68
#
#                          accuracy                           0.01      3796
#                         macro avg       0.00      0.04      0.00      3796
#                      weighted avg       0.00      0.01      0.00      3796
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
